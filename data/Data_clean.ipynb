# %%
import yfinance as yf

dat = yf.Ticker("MSFT")

# %%
yf.download("MSFT", period="", progress=False)
# Out:
# Price            Close        High     Low        Open    Volume
# Ticker            MSFT        MSFT    MSFT        MSFT      MSFT
# Date
# 2026-02-06  398.049988  400.100006  393.75  399.165009  21240384
